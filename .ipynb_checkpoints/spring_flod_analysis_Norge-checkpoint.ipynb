# %% [markdown]
# # SPRING FLOD ANALYSIS

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import sys

path = '\\\\energycorp\\applications\\OSL\\jupyter_notebooks\\personalfolders\\u39545_Sarah\\EtteranalyseLTM'
sys.path.insert(0, path)

import modules as m

# %load_ext autoreload
# %autoreload 2


#choose sheet to be name of one of the sheets in the Excel file: Etteranalyse_snow_LTM.xlsx
file = r'Etteranalyse_snow_LTM.xlsx'
sheet = 'Norg'


#Reading comments etc from Excel file: 'Etteranalyse_snow_LTM.xlsx'
all_keys, vhhQ_OBSE_list, comments_list, excluded_list, start_list, end_list = m.read_excel(sheet, file)

#Read in
df_list = m.read_from_SMG(all_keys, vhhQ_OBSE_list, sheet)

#Making new df for all models for analyis period
df_for_analysis, start_info_list, end_info_list = m.df_region_analysis(df_list)

#Calculating performance of the models
acc_perf_df, R2_perf_df = m.calc_performance(df_for_analysis, all_regions)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## BOX AND WHISKER PLOT ACCUMULATIVE DEVIATION FROM Q_OBSE

# %%
m.box_plot(acc_perf_df.drop(land))

# %% [markdown]
# ## ADJUSTMENT PERFORMANCE: ACCUMULATED DEVIATION FROM Q_OBSE

# %%
# Macke pie plot with performance for adjusted models
#m.pie_all(acc_perf_df, 'region', model='ltm')
#m.pie_all(acc_perf_df, 'region', model='temp')
m.pie_subplot_perf(acc_perf_df.drop(land), 'region', 'ref', 'spring_temp')
m.pie_subplot_perf(acc_perf_df.drop(land), 'region', 'spring_temp', 'temp')
m.pie_subplot_perf(acc_perf_df.drop(land), 'region', 'temp', 'ltm')

# %% [markdown]
# # Model Performance According to Inflow Profile Correlation (R2) and Accumulated Inflow Error

# %%
#plot performance for models in the LTM model
m.plot_perf_models(acc_perf_df, land, perfType='Accumulated')
m.plot_perf_models(R2_perf_df, land, perfType='R2')

# %% [markdown]
# # Individual Analysis for Each Model

# %%
m.make_all(df_for_analysis, df_for_analysis, all_regions, start_info_list, end_info_list, 'region', land)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#                                                         Sverige
# ------------------------------------------------------------------------------------------------------------------------
# Analysis start (2019-04-02): Peak of snow magasine for ref inndatasett.
# Analysis end (2019-07-25): First day when the inflow models are close to Q_OBSE, one week after the snow magasine goes under 20 GWh SWE.
#
# Accumulated performance [percentage deviation]: ref: -0.49, spring_temp: -2.41, temp: -2.41, ltm: -0.59
# Profile correlation performance [R2 value]: ref: 0.95, spring_temp: 0.96, temp: 0.96, ltm: 0.98
# ------------------------------------------------------------------------------------------------------------------------
#                                                         Reg1
# ...
