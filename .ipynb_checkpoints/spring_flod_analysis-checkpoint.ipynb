# %% [markdown]
# # SPRING FLOD ANALYSIS
#
# 1. Click box below and choose sheet in excel that you want to do an analysis for.
# 2. Click on Cell -> Run All

# %%
#Choosing LTM model
# Norg, Sver, LTM1,..LTM8, LTMS
sheet = 'Sver'

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import sys

path = '\\\\energycorp\\applications\\OSL\\jupyter_notebooks\\personalfolders\\u39545_Sarah\\EtteranalyseLTM'
sys.path.insert(0, path)

import modules as m

# %load_ext autoreload
# %autoreload 2

print('\n------------------------------------------------------------------------------------------------------\n')
print('                                                  {}                                                '.format(sheet))
print('\n------------------------------------------------------------------------------------------------------\n')
file = r'spring_flod_analysis.xlsx'

#Reading comments etc from Excel file: 'Etteranalyse_snow_LTM.xlsx'
all_keys, vhhQ_OBSE_list, comments_list, excluded_list, start_list, end_list = m.read_excel(sheet, file)
print(all_keys[:][:])
    
#Reading in all keys from SMG
all_df = m.read_from_SMG(all_keys, vhhQ_OBSE_list, sheet)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ------------------------------------------------------------------------------------------------------
#
#                                                   Sver
#
# ------------------------------------------------------------------------------------------------------
#
# ['Sverige' 'Reg1' 'Reg2' 'Reg3' 'Reg4']

# %%
import pytz
import time
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib as mpl
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import numpy as np
import pandas as pd
import xlsxwriter
import datetime

#Read from excel the color of each week with snow adjustmets
Sheet = pd.read_excel(file,'Snow updates') 
adjusted_weeks = Sheet['Registrated Week:'].values
adjusted_weeks_colors = Sheet['Color:'].values
colors_adj = dict(zip(adjusted_weeks, adjusted_weeks_colors))
print(colors_adj)

if sheet[0:3] != 'LTM':
    for df, key in zip(all_df, all_keys[:]):
        m.plot_prognosis(file, df, key, sheet, colors_adj)
# Out:
# {'u09': 'blue', 'u10': 'lime', 'u12': 'red', 'u16': 'brown', 'u22': 'hotpink', 'u24': 'orange', 'u25': 'mediumpurple', 'u26': 'darkmagenta'}

# %%
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

alist=['u24', 'u25', 'u22']

alist.sort(key=natural_keys)
print(alist)
# Out:
# ['u22', 'u24', 'u25']

# %%
#Making new df for all models for analyis period
df_analysis_period, start_info_list, end_info_list = m.df_analysis_period(all_df, start_list, end_list, sheet)

#Excluding columns that are chosen to be excluded in the Excel document
df_for_analysis, keys_for_analysis = m.exclude_keys(df_analysis_period, all_keys, excluded_list)

#Calculating performance of the models
acc_perf_all, R2_perf_all = m.calc_performance(df_for_analysis, keys_for_analysis)
if sheet == 'Norg':
    acc_perf = acc_perf_all.drop('Norge')
elif sheet == 'Sver':
    acc_perf = acc_perf_all.drop('Sverige')
else:
    acc_perf = acc_perf_all
# Out:
# Excluded in this analysis:
# Reg4

# %% [markdown]
# ## BOX AND WHISKER PLOT ACCUMULATIVE DEVIATION FROM Q_OBSE

# %%
m.box_plot(acc_perf)

# %% [markdown]
# # Performance According to Accumulated Deviation from Q_OBSE
# ## ADJUSTMENTS: BETTER or WORSE

# %%
# Macke pie plot with performance for adjusted models
m.pie_subplot_perf(acc_perf, sheet, 'ref', 'spring_temp')
m.pie_subplot_perf(acc_perf, sheet, 'spring_temp', 'temp')
m.pie_subplot_perf(acc_perf, sheet, 'spring_temp', 'ltm')
#m.pie_subplot_perf(acc_perf_df, ltm, what='snow')

# %% [markdown]
# # Performance According to Accumulated Inflow [%] Error and Inflow Profile Correlation (R2)

# %%
#plot performance for models in the LTM model
m.plot_perf_models(acc_perf_all, land=False, perfType='Accumulated')
m.plot_perf_models(R2_perf_all, land=False, perfType='R2')

# %% [markdown]
# # Induvidual Analysis for Each Model

# %%
m.make_all(df_analysis_period, all_df, all_keys, start_info_list, end_info_list, sheet, vhhQ_OBSE_list, comments_list, excluded_list, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b18ce2bd27de> in <module>
# ----> 1 m.make_all(df_analysis_period, all_df, all_keys, start_info_list, end_info_list, sheet, vhhQ_OBSE_list, comments_list, excluded_list)
#
# \\energycorp\applications\OSL\jupyter_notebooks\personalfolders\u39545_Sarah\EtteranalyseLTM\modules.py in make_all(df_analysis, all_df, all_keys, start_info_list, end_info_list, sheet, vhhQ_OBSE_list, comments_list, excluded_list)
#     303
#     304     #Read from excel the color of each week with snow adjustmets
# --> 305     Sheet = pd.read_excel(file,'Snow updates')
#     306     adjusted_weeks = Sheet['Registrated Week:'].values
#     307     adjusted_weeks_colors = Sheet['Color:'].values
#
# NameError: name 'file' is not defined
